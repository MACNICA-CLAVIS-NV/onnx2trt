# %% [markdown]
# # Converting ONNX Model to TensorRT Engine

# %%
import urllib
import os
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import tensorrt as trt
import common
import trt_analyzer
import time
import functools

# %%
onnx_file = 'alexnet.onnx'
os.environ['ONNX_FILE'] = onnx_file

f = os.path.splitext(os.path.basename(onnx_file))[0]
engine_file = f + '.trt'
os.environ['ENGINE_FILE'] = engine_file

profile_file = 'profile.json'
os.environ['PROFILE_FILE'] = profile_file

# %%
if os.path.exists(onnx_file):
    print('ONNX model file: {}'.format(onnx_file))
else:
    print('*** ERROR! ONNX model file {} not found. ***'.format(onnx_file))
    print('*** Upload the model file! ***')
    raise Exception()
# Out:
# ONNX model file: alexnet.onnx

# %% [markdown]
# ## Prepare test source image and the ImageNet labels

# %%
def download_file(url, file=None):
    if file is None:
        file = os.path.basename(url)
    if os.path.exists(file):
        return file
    try:
        urllib.URLopener().retrieve(url, file)
    except:
        urllib.request.urlretrieve(url, file)
    return file

# %% [markdown]
# Specify a input image file.

# %%
image_file = download_file('https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/doc/tutorials/python/predict_image/cat.jpg')
#image_file = download_file('https://github.com/pytorch/hub/raw/master/dog.jpg')
#image_file = download_file('https://upload.wikimedia.org/wikipedia/commons/b/b5/Canadian_Golden_Retriever.jpeg')

# %% [markdown]
# Download the ImageNet class file and convert it to Python list.

# %%
class_file = download_file('http://data.mxnet.io/models/imagenet/synset.txt')
with open(class_file, 'r') as f:
    labels = [l.rstrip() for l in f]

# %% [markdown]
# Normlize the input image in the ImageNet training image conditions, and transpose it to NCHW format.

# %%
def center_crop(img, width, height):
    src_width, src_height = img.size
    left = (src_width - width) // 2
    upper = (src_height - height) // 2
    right = left + width
    lower = upper + height
    img = img.crop((left, upper, right, lower))
    return img

# %%
def preprocess_imagenet(image):
    short = min(image.size)
    image = center_crop(image, short, short)
    image = image.resize((224, 224), resample=Image.BICUBIC)
    image = np.array(image, dtype=np.float32)
    image /= 255.0
    image -= [0.485, 0.456, 0.406]
    image /= [0.229, 0.224, 0.225]
    image = np.clip(image, 0, 1)
    return image

# %%
input_image = Image.open(image_file)
plt.imshow(input_image)
plt.show()

input_image = preprocess_imagenet(input_image)
plt.imshow(input_image)
plt.show()

input_batch = input_image[np.newaxis]
input_batch = input_batch.transpose((0, 3, 1, 2))
input_batch = np.array(input_batch, dtype=input_batch.dtype, order='C')

# %% [markdown]
# ## Model conversion by trtexec

# %%
# !/usr/src/tensorrt/bin/trtexec --onnx=${ONNX_FILE} --saveEngine=${ENGINE_FILE} --workspace=2048 --exportProfile=${PROFILE_FILE}
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8001] # /usr/src/tensorrt/bin/trtexec --onnx=alexnet.onnx --saveEngine=alexnet.trt --workspace=2048 --exportProfile=profile.json
# [11/24/2021-04:42:08] [I] === Model Options ===
# [11/24/2021-04:42:08] [I] Format: ONNX
# [11/24/2021-04:42:08] [I] Model: alexnet.onnx
# [11/24/2021-04:42:08] [I] Export profile to JSON file: profile.json
# [11/24/2021-04:42:08] [I]
# [11/24/2021-04:42:08] [I] === Device Information ===
# [11/24/2021-04:42:08] [I] Selected Device: Xavier
# [11/24/2021-04:42:08] [I] Compute Capability: 7.2
# [11/24/2021-04:42:08] [I] SMs: 6
# [11/24/2021-04:42:08] [I] Compute Clock Rate: 1.109 GHz
# [11/24/2021-04:42:08] [I] Device Global Memory: 7773 MiB
# [11/24/2021-04:42:08] [I] Shared Memory per SM: 96 KiB
# [11/24/2021-04:42:08] [I] Memory Bus Width: 256 bits (ECC disabled)
# [11/24/2021-04:42:08] [I] Memory Clock Rate: 1.109 GHz
# [11/24/2021-04:42:08] [I]
# [11/24/2021-04:42:08] [I] TensorRT version: 8001
# [11/24/2021-04:42:10] [I] [TRT] [MemUsageChange] Init CUDA: CPU +354, GPU +0, now: CPU 372, GPU 5083 (MiB)
# [11/24/2021-04:42:10] [I] Start parsing network model
# [11/24/2021-04:42:10] [I] [TRT] ----------------------------------------------------------------
# [11/24/2021-04:42:10] [I] [TRT] Input filename:   alexnet.onnx
# [11/24/2021-04:42:10] [I] [TRT] ONNX IR version:  0.0.8
# [11/24/2021-04:42:10] [I] [TRT] Opset version:    15
# [11/24/2021-04:42:10] [I] [TRT] Producer name:
# [11/24/2021-04:42:10] [I] [TRT] Producer version:
# [11/24/2021-04:42:10] [I] [TRT] Domain:
# [11/24/2021-04:42:10] [I] [TRT] Model version:    0
# [11/24/2021-04:42:10] [I] [TRT] Doc string:
# [11/24/2021-04:42:10] [I] [TRT] ----------------------------------------------------------------
# [11/24/2021-04:42:11] [I] Finish parsing network model
# [11/24/2021-04:42:11] [I] [TRT] [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 605, GPU 5342 (MiB)
# [11/24/2021-04:42:11] [I] [TRT] [MemUsageSnapshot] Builder begin: CPU 605 MiB, GPU 5342 MiB
# [11/24/2021-04:42:11] [I] [TRT] ---------- Layers Running on DLA ----------
# [11/24/2021-04:42:11] [I] [TRT] ---------- Layers Running on GPU ----------
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_conv0_fwd + alexnet0_conv0_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_pool0_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_conv1_fwd + alexnet0_conv1_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_pool1_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_conv2_fwd + alexnet0_conv2_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_conv3_fwd + alexnet0_conv3_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_conv4_fwd + alexnet0_conv4_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_pool2_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_flatten0_flatten0 + (Unnamed Layer* 14) [Shuffle]
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_dense0_fwd + alexnet0_dense0_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] squeeze_after_alexnet0_dense0_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] (Unnamed Layer* 18) [Identity]
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] (Unnamed Layer* 19) [Shuffle]
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_dense1_fwd + alexnet0_dense1_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] squeeze_after_alexnet0_dense1_relu_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] (Unnamed Layer* 23) [Identity]
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] (Unnamed Layer* 24) [Shuffle]
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] alexnet0_dense2_fwd
# [11/24/2021-04:42:11] [I] [TRT] [GpuLayer] (Unnamed Layer* 26) [Shuffle]
# [11/24/2021-04:42:12] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +226, GPU +207, now: CPU 831, GPU 5549 (MiB)
# [11/24/2021-04:42:14] [I] [TRT] [MemUsageChange] Init cuDNN: CPU +307, GPU +306, now: CPU 1138, GPU 5855 (MiB)
# [11/24/2021-04:42:14] [W] [TRT] Detected invalid timing cache, setup a local cache instead
# [11/24/2021-04:42:36] [I] [TRT] Some tactics do not have sufficient workspace memory to run. Increasing workspace size may increase performance, please check verbose output.
# [11/24/2021-04:42:56] [I] [TRT] Detected 1 inputs and 1 output network tensors.
# [11/24/2021-04:42:57] [I] [TRT] Total Host Persistent Memory: 12576
# [11/24/2021-04:42:57] [I] [TRT] Total Device Persistent Memory: 108660736
# [11/24/2021-04:42:57] [I] [TRT] Total Scratch Memory: 0
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 144 MiB, GPU 547 MiB
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1605, GPU 7010 (MiB)
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 1605, GPU 7010 (MiB)
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1605, GPU 7010 (MiB)
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1604, GPU 7010 (MiB)
# [11/24/2021-04:42:57] [I] [TRT] [MemUsageSnapshot] Builder end: CPU 1604 MiB, GPU 7010 MiB
# [11/24/2021-04:42:59] [I] [TRT] Loaded engine size: 247 MB
# [11/24/2021-04:42:59] [I] [TRT] [MemUsageSnapshot] deserializeCudaEngine begin: CPU 1852 MiB, GPU 7045 MiB
# [11/24/2021-04:43:00] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +10, now: CPU 1852, GPU 7209 (MiB)
# [11/24/2021-04:43:00] [I] [TRT] [MemUsageChange] Init cuDNN: CPU +0, GPU +10, now: CPU 1852, GPU 7219 (MiB)
# [11/24/2021-04:43:00] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1852, GPU 7219 (MiB)
# [11/24/2021-04:43:00] [I] [TRT] [MemUsageSnapshot] deserializeCudaEngine end: CPU 1852 MiB, GPU 7219 MiB
# [11/24/2021-04:43:07] [I] Engine built in 58.9423 sec.
# [11/24/2021-04:43:07] [I] [TRT] [MemUsageSnapshot] ExecutionContext creation begin: CPU 1371 MiB, GPU 6765 MiB
# [11/24/2021-04:43:07] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1371, GPU 6765 (MiB)
# [11/24/2021-04:43:07] [I] [TRT] [MemUsageChange] Init cuDNN: CPU +0, GPU +0, now: CPU 1371, GPU 6765 (MiB)
# [11/24/2021-04:43:07] [I] [TRT] [MemUsageSnapshot] ExecutionContext creation end: CPU 1371 MiB, GPU 6868 MiB
# [11/24/2021-04:43:07] [I] Created input binding for data with dimensions 1x3x224x224
# [11/24/2021-04:43:07] [I] Created output binding for alexnet0_dense2_fwd with dimensions 1x1000
# [11/24/2021-04:43:07] [I] Starting inference
# [11/24/2021-04:43:10] [I] Warmup completed 32 queries over 200 ms
# [11/24/2021-04:43:10] [I] Timing trace has 496 queries over 3.01395 s
# [11/24/2021-04:43:10] [I]
# [11/24/2021-04:43:10] [I] === Trace details ===
# [11/24/2021-04:43:10] [I] Trace averages of 10 runs:
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97034 ms - Host latency: 6.04683 ms (end to end 6.06076 ms, enqueue 5.97598 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98375 ms - Host latency: 6.04691 ms (end to end 6.06435 ms, enqueue 5.99508 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 6.00022 ms - Host latency: 6.07438 ms (end to end 6.08884 ms, enqueue 6.0083 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 6.00351 ms - Host latency: 6.07381 ms (end to end 6.09024 ms, enqueue 6.00662 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 6.00034 ms - Host latency: 6.06537 ms (end to end 6.08164 ms, enqueue 6.01125 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.99004 ms - Host latency: 6.05382 ms (end to end 6.06916 ms, enqueue 5.99997 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98853 ms - Host latency: 6.05061 ms (end to end 6.06967 ms, enqueue 5.99863 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98389 ms - Host latency: 6.05084 ms (end to end 6.06762 ms, enqueue 5.99517 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.96393 ms - Host latency: 6.03031 ms (end to end 6.04799 ms, enqueue 5.97473 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97177 ms - Host latency: 6.04077 ms (end to end 6.06365 ms, enqueue 5.97335 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.96437 ms - Host latency: 6.02408 ms (end to end 6.04263 ms, enqueue 5.97487 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97377 ms - Host latency: 6.03961 ms (end to end 6.06033 ms, enqueue 5.98497 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98486 ms - Host latency: 6.04874 ms (end to end 6.06827 ms, enqueue 5.99655 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98282 ms - Host latency: 6.04742 ms (end to end 6.06733 ms, enqueue 5.99483 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97593 ms - Host latency: 6.04438 ms (end to end 6.06205 ms, enqueue 5.98842 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98108 ms - Host latency: 6.04434 ms (end to end 6.06079 ms, enqueue 5.98916 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.9634 ms - Host latency: 6.02554 ms (end to end 6.04231 ms, enqueue 5.97238 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97452 ms - Host latency: 6.04016 ms (end to end 6.05823 ms, enqueue 5.98754 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.99976 ms - Host latency: 6.07188 ms (end to end 6.08926 ms, enqueue 6.01091 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98145 ms - Host latency: 6.05164 ms (end to end 6.0682 ms, enqueue 5.99275 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98065 ms - Host latency: 6.04148 ms (end to end 6.05911 ms, enqueue 5.99349 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.97902 ms - Host latency: 6.04777 ms (end to end 6.06506 ms, enqueue 5.99193 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.96589 ms - Host latency: 6.03273 ms (end to end 6.0498 ms, enqueue 5.97548 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.96864 ms - Host latency: 6.03683 ms (end to end 6.05392 ms, enqueue 5.98044 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.96063 ms - Host latency: 6.02621 ms (end to end 6.04534 ms, enqueue 5.96708 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5.98368 ms - Host latency: 6.05029 ms (end to end 6.06589 ms, enqueue 5.9942 ms)
# [11/24/2021-04:43:10] [I] Average on 10 runs - GPU latency: 5
# [11/24/2021-04:43:10] [I] GPU Compute Time: min = 5.92285 ms, max = 6.52649 ms, mean = 5.97273 ms, median = 5.96286 ms, percentile(99%) = 6.08652 ms
# [11/24/2021-04:43:10] [I] D2H Latency: min = 0.0197754 ms, max = 0.0852051 ms, mean = 0.0256854 ms, median = 0.0224609 ms, percentile(99%) = 0.060791 ms
# [11/24/2021-04:43:10] [I] Total Host Walltime: 3.01395 s
# [11/24/2021-04:43:10] [I] Total GPU Compute Time: 2.96247 s
# [11/24/2021-04:43:10] [W] * Throughput may be bound by Enqueue Time rather than GPU Compute and the GPU may be under-utilized.
# [11/24/2021-04:43:10] [W]   If not already in use, --useCudaGraph (utilize CUDA graphs where possible) may increase the throughput.
# [11/24/2021-04:43:10] [I] Explanations of the performance metrics are printed in the verbose logs.
# [11/24/2021-04:43:10] [I]
# &&&& PASSED TensorRT.trtexec [TensorRT v8001] # /usr/src/tensorrt/bin/trtexec --onnx=alexnet.onnx --saveEngine=alexnet.trt --workspace=2048 --exportProfile=profile.json
# [11/24/2021-04:43:10] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +0, GPU +0, now: CPU 1371, GPU 6841 (MiB)

# %%
pd.read_json(profile_file)
# Out:
#     count                                            name      timeMs  \
# 0   528.0                                             NaN         NaN
# 1     NaN    alexnet0_conv0_fwd + alexnet0_conv0_relu_fwd   122.21500
# 2     NaN                              alexnet0_pool0_fwd    13.54600
# 3     NaN    alexnet0_conv1_fwd + alexnet0_conv1_relu_fwd   312.91900
# 4     NaN                              alexnet0_pool1_fwd     9.26505
# 5     NaN    alexnet0_conv2_fwd + alexnet0_conv2_relu_fwd   124.61800
# 6     NaN    alexnet0_conv3_fwd + alexnet0_conv3_relu_fwd   172.04600
# 7     NaN    alexnet0_conv4_fwd + alexnet0_conv4_relu_fwd   118.46400
# 8     NaN                              alexnet0_pool2_fwd     5.09725
# 9     NaN  alexnet0_dense0_fwd + alexnet0_dense0_relu_fwd  1419.76000
# 10    NaN  alexnet0_dense1_fwd + alexnet0_dense1_relu_fwd   655.52200
# 11    NaN                             alexnet0_dense2_fwd   165.24600
#
#     averageMs  percentage
# 0         NaN         NaN
# 1    0.231468    3.918790
# 2    0.025655    0.434349
# 3    0.592649   10.033600
# 4    0.017548    0.297081
# 5    0.236020    3.995850
# 6    0.325844    5.516590
# 7    0.224364    3.798520
# 8    0.009654    0.163442
# 9    2.688930   45.524100
# 10   1.241520   21.019100
# 11   0.312966    5.298570

# %% [markdown]
# ## Do inference by TensorRT

# %% [markdown]
# Prepare the explicit batch flag for TensorRT.

# %%
EXPLICIT_BATCH = 1 << (int)(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)

# %% [markdown]
# Define a function to generate a TensorRT engine from a ONNX model.

# %%
TRT_LOGGER = trt.Logger(trt.Logger.VERBOSE)

def get_engine(onnx_file_path, engine_file_path=None):
    """Attempts to load a serialized engine if available, otherwise builds a new TensorRT engine and saves it."""
    def build_engine():
        """Takes an ONNX file and creates a TensorRT engine to run inference with"""
        with trt.Builder(TRT_LOGGER) as builder, builder.create_network(common.EXPLICIT_BATCH) as network, trt.OnnxParser(network, TRT_LOGGER) as parser, builder.create_builder_config() as config, trt.Runtime(TRT_LOGGER) as runtime:
            config.max_workspace_size = 1 << 29 # 512MiB
            builder.max_batch_size = 1
            # Parse model file
            if not os.path.exists(onnx_file_path):
                print('ONNX file {} not found.'.format(onnx_file_path))
                exit(0)
            print('Loading ONNX file from path {}...'.format(onnx_file_path))
            with open(onnx_file_path, 'rb') as model:
                print('Beginning ONNX file parsing')
                if not parser.parse(model.read()):
                    print ('ERROR: Failed to parse the ONNX file.')
                    for error in range(parser.num_errors):
                        print (parser.get_error(error))
                    return None
            network.get_input(0).shape = [1, 3, 224, 224]
            print('Completed parsing of ONNX file')
            # Get network info
            global net_dict
            net_dict = trt_analyzer.network_dict(network)
            print('Building an engine from file {}; this may take a while...'.format(onnx_file_path))
            plan = builder.build_serialized_network(network, config)
            engine = runtime.deserialize_cuda_engine(plan)
            print("Completed creating Engine")
            with open(engine_file_path, "wb") as f:
                f.write(engine.serialize())
            return engine

    if engine_file_path is None:
        f = os.path.splitext(os.path.basename(onnx_file_path))[0]
        engine_file_path = f + '.trt'
        
    if os.path.exists(engine_file_path):
        # If a serialized engine exists, use it instead of building an engine.
        print("Reading engine from file {}".format(engine_file_path))
        with open(engine_file_path, "rb") as f, trt.Runtime(TRT_LOGGER) as runtime:
            return runtime.deserialize_cuda_engine(f.read())
    else:
        return build_engine()

# %% [markdown]
# Export the ONNX model to a TensorRT engine and do inference with it.

# %%
# Remove the engine file generated by trtexec so that the following code will regenerate the engine file.
if os.path.exists(engine_file):
    os.remove(engine_file)

net_dict = None
with get_engine(onnx_file, engine_file) as engine, engine.create_execution_context() as context:
    inputs, outputs, bindings, stream = common.allocate_buffers(engine)
    inputs[0].host = input_batch
    trt_outputs = common.do_inference_v2( \
        context, bindings=bindings, inputs=inputs, outputs=outputs, stream=stream)
    trt_outputs[0] = np.exp(trt_outputs[0])/sum(np.exp(trt_outputs[0]))
    idxlist = np.argsort(trt_outputs[0])[:-6:-1]
    for i in idxlist:
        print('{}:\t{}'.format(labels[i], trt_outputs[0][i]))
# Out:
# Loading ONNX file from path alexnet.onnx...
# Beginning ONNX file parsing
# Completed parsing of ONNX file
# Building an engine from file alexnet.onnx; this may take a while...
# Completed creating Engine
# n02123159 tiger cat:	0.43930506706237793
# n02124075 Egyptian cat:	0.24557574093341827
# n02123045 tabby, tabby cat:	0.1896245777606964
# n02127052 lynx, catamount:	0.031130827963352203
# n02909870 bucket, pail:	0.018238719552755356

# %% [markdown]
# Print the TensorRT network.

# %%
pd.DataFrame(net_dict)
# Out:
#                               Name                       Type  \
# 0               alexnet0_conv0_fwd      LayerType.CONVOLUTION
# 1          alexnet0_conv0_relu_fwd       LayerType.ACTIVATION
# 2               alexnet0_pool0_fwd          LayerType.POOLING
# 3               alexnet0_conv1_fwd      LayerType.CONVOLUTION
# 4          alexnet0_conv1_relu_fwd       LayerType.ACTIVATION
# 5               alexnet0_pool1_fwd          LayerType.POOLING
# 6               alexnet0_conv2_fwd      LayerType.CONVOLUTION
# 7          alexnet0_conv2_relu_fwd       LayerType.ACTIVATION
# 8               alexnet0_conv3_fwd      LayerType.CONVOLUTION
# 9          alexnet0_conv3_relu_fwd       LayerType.ACTIVATION
# 10              alexnet0_conv4_fwd      LayerType.CONVOLUTION
# 11         alexnet0_conv4_relu_fwd       LayerType.ACTIVATION
# 12              alexnet0_pool2_fwd          LayerType.POOLING
# 13      alexnet0_flatten0_flatten0          LayerType.SHUFFLE
# 14   (Unnamed Layer* 14) [Shuffle]          LayerType.SHUFFLE
# 15             alexnet0_dense0_fwd  LayerType.FULLY_CONNECTED
# 16   (Unnamed Layer* 16) [Shuffle]          LayerType.SHUFFLE
# 17        alexnet0_dense0_relu_fwd       LayerType.ACTIVATION
# 18  (Unnamed Layer* 18) [Identity]         LayerType.IDENTITY
# 19   (Unnamed Layer* 19) [Shuffle]          LayerType.SHUFFLE
# 20             alexnet0_dense1_fwd  LayerType.FULLY_CONNECTED
# 21   (Unnamed Layer* 21) [Shuffle]          LayerType.SHUFFLE
# 22        alexnet0_dense1_relu_fwd       LayerType.ACTIVATION
# 23  (Unnamed Layer* 23) [Identity]         LayerType.IDENTITY
# 24   (Unnamed Layer* 24) [Shuffle]          LayerType.SHUFFLE
# 25             alexnet0_dense2_fwd  LayerType.FULLY_CONNECTED
# 26   (Unnamed Layer* 26) [Shuffle]          LayerType.SHUFFLE
#
#                Inputs            Outputs  \
# 0    (1, 3, 224, 224)    (1, 64, 55, 55)
# 1     (1, 64, 55, 55)    (1, 64, 55, 55)
# 2     (1, 64, 55, 55)    (1, 64, 27, 27)
# 3     (1, 64, 27, 27)   (1, 192, 27, 27)
# 4    (1, 192, 27, 27)   (1, 192, 27, 27)
# 5    (1, 192, 27, 27)   (1, 192, 13, 13)
# 6    (1, 192, 13, 13)   (1, 384, 13, 13)
# 7    (1, 384, 13, 13)   (1, 384, 13, 13)
# 8    (1, 384, 13, 13)   (1, 256, 13, 13)
# 9    (1, 256, 13, 13)   (1, 256, 13, 13)
# 10   (1, 256, 13, 13)   (1, 256, 13, 13)
# 11   (1, 256, 13, 13)   (1, 256, 13, 13)
# 12   (1, 256, 13, 13)     (1, 256, 6, 6)
# 13     (1, 256, 6, 6)          (1, 9216)
# 14          (1, 9216)    (1, 9216, 1, 1)
# 15    (1, 9216, 1, 1)    (1, 4096, 1, 1)
# 16    (1, 4096, 1, 1)          (1, 4096)
# 17          (1, 4096)          (1, 4096)
# 18          (1, 4096)          (1, 4096)
# 19          (1, 4096)    (1, 4096, 1, 1)
# 20    (1, 4096, 1, 1)    (1, 4096, 1, 1)
# 21    (1, 4096, 1, 1)          (1, 4096)
# 22          (1, 4096)          (1, 4096)
# 23          (1, 4096)          (1, 4096)
# 24          (1, 4096)    (1, 4096, 1, 1)
# 25    (1, 4096, 1, 1)    (1, 1000, 1, 1)
# 26    (1, 1000, 1, 1)          (1, 1000)
#
#                                  Type Specific Params
# 0       ksz=(11, 11) maps=64 stride=(4, 4) pad=(0, 0)
# 1                            type=ActivationType.RELU
# 2   type=PoolingType.MAX wsize=(3, 3) stride=(2, 2...
# 3        ksz=(5, 5) maps=192 stride=(1, 1) pad=(0, 0)
# 4                            type=ActivationType.RELU
# 5   type=PoolingType.MAX wsize=(3, 3) stride=(2, 2...
# 6        ksz=(3, 3) maps=384 stride=(1, 1) pad=(0, 0)
# 7                            type=ActivationType.RELU
# 8        ksz=(3, 3) maps=256 stride=(1, 1) pad=(0, 0)
# 9                            type=ActivationType.RELU
# 10       ksz=(3, 3) maps=256 stride=(1, 1) pad=(0, 0)
# 11                           type=ActivationType.RELU
# 12  type=PoolingType.MAX wsize=(3, 3) stride=(2, 2...
# 13
# 14
# 15                                      channels=4096
# 16
# 17                           type=ActivationType.RELU
# 18
# 19
# 20                                      channels=4096
# 21
# 22                           type=ActivationType.RELU
# 23
# 24
# 25                                      channels=1000
# 26

# %% [markdown]
# ## Measure inference processing time

# %% [markdown]
# Define a decorator function to measure processing times.

# %%
def processing_time(num_times, warmups=0):
    def _processing_time(func):
        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            for i in range(warmups):
                ret = func(*args, **kwargs)
            t0 = time.time()
            for i in range(num_times):
                ret = func(*args, **kwargs)
            t1 = time.time()
            print('Average a {0} times trial: {1:,f}sec'.format(num_times, (t1 - t0) / num_times))
            return ret
        return wrapper
    return _processing_time

# %% [markdown]
# Define a test function with the pocessing time measurement decorator.

# %%
@processing_time(100, 10)
def test_inference(context, bindings, inputs, outputs, stream):
    trt_outputs = common.do_inference_v2( \
        context, bindings=bindings, inputs=inputs, outputs=outputs, stream=stream)
    return trt_outputs

# %% [markdown]
# Measure inference processing time.

# %%
with open(engine_file, "rb") as f, trt.Runtime(TRT_LOGGER) as runtime:
    with runtime.deserialize_cuda_engine(f.read()) as engine, engine.create_execution_context() as context:
        inputs, outputs, bindings, stream = common.allocate_buffers(engine)
        inputs[0].host = input_batch
        trt_outputs = test_inference( \
            context, bindings=bindings, inputs=inputs, outputs=outputs, stream=stream)
        trt_outputs[0] = np.exp(trt_outputs[0])/sum(np.exp(trt_outputs[0]))
        idxlist = np.argsort(trt_outputs[0])[:-6:-1]
        for i in idxlist:
            print('{}:\t{}'.format(labels[i], trt_outputs[0][i]))
# Out:
# Average a 100 times trial: 0.006246sec
# n02123159 tiger cat:	0.43930506706237793
# n02124075 Egyptian cat:	0.24557574093341827
# n02123045 tabby, tabby cat:	0.1896245777606964
# n02127052 lynx, catamount:	0.031130827963352203
# n02909870 bucket, pail:	0.018238719552755356
